# %%
import pandas as pd

# Load the datasets
deliveries_df = pd.read_csv('./data/raw/deliveries.csv')
matches_df = pd.read_csv('./data/raw/Cricket_data.csv')

# Show column names
print("Deliveries columns:", deliveries_df.columns.tolist())
print("Matches columns:", matches_df.columns.tolist())

# Show a few rows of each to understand the data structure
print("\nDeliveries sample:")
print(deliveries_df.head())

print("\nMatches sample:")
print(matches_df.head())
# Out:
# Deliveries columns: ['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball', 'batter', 'bowler', 'non_striker', 'batsman_runs', 'extra_runs', 'total_runs', 'extras_type', 'is_wicket', 'player_dismissed', 'dismissal_kind', 'fielder']
# Matches columns: ['season', 'id', 'name', 'short_name', 'description', 'home_team', 'away_team', 'toss_won', 'decision', '1st_inning_score', '2nd_inning_score', 'winner', 'result', 'start_date', 'end_date', 'venue_id', 'venue_name', 'home_captain', 'away_captain', 'pom', 'points', 'super_over', 'home_overs', 'home_runs', 'home_wickets', 'home_boundaries', 'away_overs', 'away_runs', 'away_wickets', 'away_boundaries', 'highlights', 'home_key_batsman', 'home_key_bowler', 'home_playx1', 'away_playx1', 'away_key_batsman', 'away_key_bowler', 'match_days', 'umpire1', 'umpire2', 'tv_umpire', 'referee', 'reserve_umpire']
#
# Deliveries sample:
#    match_id  inning           batting_team                 bowling_team  over  \
# ...
